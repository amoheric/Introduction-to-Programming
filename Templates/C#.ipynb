// %% [markdown]
// <a href="https://colab.research.google.com/github/amoheric/Introduction-to-Programming/blob/main/Templates/C%23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

// %% [markdown]
// **Warning!**
//
// *To activate the C# kernel, follow these steps:*
//
// * Run the code of the next cell and wait for its completion.
//
// * Refresh the browser page (in most cases, this can be done by pressing the F5 key).
//
// * **Run your C# cells!**

// %%
#@title Prepare Google Colab for C# Kernel

# Install dotnet

!sudo apt-get update -qq &> /dev/null
!sudo apt-get install -y dotnet-sdk-7.0 -qq &> /dev/null

# Install jupyter kernel

!dotnet tool install --tool-path /usr/bin --version 1.0.360602 Microsoft.dotnet-interactive &> /dev/null
!dotnet interactive jupyter install &> /dev/null

# Create proxy file

with open("ipc_proxy_kernel.py", "w") as f:
    f.write("""import zmq;
import json;
import argparse;
from threading import Thread;
from traitlets.traitlets import Type;
from jupyter_client import KernelClient;
from jupyter_client.session import Session;
from jupyter_client.channels import HBChannel;
from jupyter_client.manager import KernelManager;

parser = argparse.ArgumentParser();
parser.add_argument("connection_file");
parser.add_argument("--kernel", type = str, required = True);
args = parser.parse_args();

# parse connection file details
with open(args.connection_file, "r") as connection_file:
    connection_file_contents = json.load(connection_file);
    transport = str(connection_file_contents["transport"]);
    ip = str(connection_file_contents["ip"]);
    shell_port = int(connection_file_contents["shell_port"]);
    stdin_port = int(connection_file_contents["stdin_port"]);
    control_port = int(connection_file_contents["control_port"]);
    iopub_port = int(connection_file_contents["iopub_port"]);
    hb_port = int(connection_file_contents["hb_port"]);
    signature_scheme = str(connection_file_contents["signature_scheme"]);
    key = str(connection_file_contents["key"]).encode();
# channel | kernel_type | client_type
# shell   | ROUTER      | DEALER
# stdin   | ROUTER      | DEALER
# ctrl    | ROUTER      | DEALER
# iopub   | PUB         | SUB
# hb      | REP         | REQ
zmq_context = zmq.Context()

def create_and_bind_socket(port: int, socket_type: int):
    if(port <= 0):
        raise ValueError(f"Invalid port: {port}");
    if(transport == "tcp"):
        addr = f"tcp://{ip}:{port}";
    elif(transport == "ipc"):
        addr = f"ipc://{ip}-{port}";
    else:
        raise ValueError(f"Unknown transport: {transport}");
    socket: zmq.Socket = zmq_context.socket(socket_type);
    socket.linger = 1000; # ipykernel does this
    socket.bind(addr);
    return socket;

shell_socket = create_and_bind_socket(shell_port, zmq.ROUTER);
stdin_socket = create_and_bind_socket(stdin_port, zmq.ROUTER);
control_socket = create_and_bind_socket(control_port, zmq.ROUTER);
iopub_socket = create_and_bind_socket(iopub_port, zmq.PUB);
hb_socket = create_and_bind_socket(hb_port, zmq.REP);
# Proxy and the real kernel have their own heartbeats. (shoutout to ipykernel
# for this neat little heartbeat implementation)
Thread(target = zmq.device, args = (zmq.QUEUE, hb_socket, hb_socket)).start();

def ZMQProxyChannel_factory(proxy_server_socket: zmq.Socket):
    class ZMQProxyChannel(object):
        kernel_client_socket: zmq.Socket = None;
        session: Session = None;

        def __init__(self, socket: zmq.Socket, session: Session, _ = None):
            super().__init__();
            self.kernel_client_socket = socket;
            self.session = session;

        def start(self):
            # Very convenient zmq device here, proxy will handle the actual zmq
            # proxying on each of our connected sockets (other than heartbeat).
            # It blocks while they are connected so stick it in a thread.
            Thread(
                target = zmq.proxy,
                args = (proxy_server_socket, self.kernel_client_socket)
            ).start();

        def stop(self):
            if(self.kernel_client_socket is not None):
                try:
                    self.kernel_client_socket.close(linger = 0);
                except Exception:
                    pass;
                self.kernel_client_socket = None;

        def is_alive(self):
            return self.kernel_client_socket is not None;

    return ZMQProxyChannel

class ProxyKernelClient(KernelClient):
    shell_channel_class = Type(ZMQProxyChannel_factory(shell_socket));
    stdin_channel_class = Type(ZMQProxyChannel_factory(stdin_socket));
    control_channel_class = Type(ZMQProxyChannel_factory(control_socket));
    iopub_channel_class = Type(ZMQProxyChannel_factory(iopub_socket));
    hb_channel_class = Type(HBChannel);


kernel_manager = KernelManager();
kernel_manager.kernel_name = args.kernel;
kernel_manager.transport = "tcp";
kernel_manager.client_factory = ProxyKernelClient;
kernel_manager.autorestart = False;
# Make sure the wrapped kernel uses the same session info. This way we don't
# need to decode them before forwarding, we can directly pass everything
# through.
kernel_manager.session.signature_scheme = signature_scheme;
kernel_manager.session.key = key;
kernel_manager.start_kernel();
# Connect to the real kernel we just started and start up all the proxies.
kernel_client: ProxyKernelClient = kernel_manager.client();
kernel_client.start_channels();
# Everything should be up and running. We now just wait for the managed kernel
# process to exit and when that happens, shutdown and exit with the same code.
exit_code = kernel_manager.kernel.wait();
kernel_client.stop_channels();
zmq_context.destroy(0);
exit(exit_code);""");

# Install proxy

import os;
import sys;
import json;
import shutil;
import os.path;
from jupyter_client.kernelspec import KernelSpec, KernelSpecManager, NoSuchKernel;

kernel_spec_manager = KernelSpecManager();
real_kernel_spec: KernelSpec = kernel_spec_manager.get_kernel_spec(".net-csharp");
real_kernel_install_path = real_kernel_spec.resource_dir;
new_kernel_name = ".net-csharp_tcp";
new_kernel_install_path = os.path.join(
    os.path.dirname(real_kernel_install_path), new_kernel_name
);
shutil.move(real_kernel_install_path, new_kernel_install_path);
# Update the moved kernel name and args. We tag it _tcp because the proxy will
# impersonate it and should be the one using the real name.
new_kernel_json_path = os.path.join(new_kernel_install_path, "kernel.json");
with open(new_kernel_json_path, "r") as in_:
    real_kernel_json = json.load(in_);
    real_kernel_json["name"] = new_kernel_name;
    real_kernel_json["argv"] = list(
        map(
            lambda arg: arg.replace(real_kernel_install_path, new_kernel_install_path),
            real_kernel_json["argv"]
        )
    );
with open(new_kernel_json_path, "w") as out:
    json.dump(real_kernel_json, out);
os.makedirs(real_kernel_install_path)
proxy_kernel_implementation_path = os.path.join(
    real_kernel_install_path, "ipc_proxy_kernel.py"
);
proxy_kernel_spec = KernelSpec();
proxy_kernel_spec.argv = [
    sys.executable,
    proxy_kernel_implementation_path,
    "{connection_file}",
    f"--kernel={new_kernel_name}"
];
proxy_kernel_spec.display_name = real_kernel_spec.display_name;
proxy_kernel_spec.interrupt_mode = real_kernel_spec.interrupt_mode or "message";
proxy_kernel_spec.language = real_kernel_spec.language;
proxy_kernel_json_path = os.path.join(real_kernel_install_path, "kernel.json");
with open(proxy_kernel_json_path, "w") as out:
    json.dump(proxy_kernel_spec.to_dict(), out, indent = 2);
new_name = shutil.copy("ipc_proxy_kernel.py", proxy_kernel_implementation_path);
!rm ipc_proxy_kernel.py
// Out:
// (1,1): error CS1024: Preprocessor directive expected
//
// (3,3): error CS1024: Preprocessor directive expected
//
// (5,7): error CS1002: ; expected
//
// (5,15): error CS1002: ; expected
//
// (5,27): error CS1525: Invalid expression term '>'
//
// (5,29): error CS1525: Invalid expression term '/'
//
// (6,2): error CS1002: ; expected
//
// (6,10): error CS1002: ; expected
//
// (6,15): error CS1002: ; expected
//
// (6,26): error CS1002: ; expected
//
// (6,46): error CS1525: Invalid expression term '>'
//
// (6,48): error CS1525: Invalid expression term '/'
//
// (8,3): error CS1024: Preprocessor directive expected
//
// (10,2): error CS1002: ; expected
//
// (10,14): error CS1002: ; expected
//
// (10,24): error CS1002: ; expected
//
// (10,45): error CS1002: ; expected
//
// (10,53): error CS1002: ; expected
//
// (10,56): error CS1002: ; expected
//
// (10,64): error CS1002: ; expected
//
// (10,94): error CS1525: Invalid expression term '>'
//
// (10,96): error CS1525: Invalid expression term '/'
//
// (11,2): error CS1002: ; expected
//
// (11,21): error CS1002: ; expected
//
// (11,37): error CS1002: ; expected
//
// (11,38): error CS1525: Invalid expression term '>'
//
// (11,40): error CS1525: Invalid expression term '/'
//
// (11,49): error CS1002: ; expected
//
// (13,3): error CS1024: Preprocessor directive expected
//
// (15,11): error CS1001: Identifier expected
//
// (15,32): error CS1031: Type expected
//
// (15,32): error CS1001: Identifier expected
//
// (15,34): error CS1031: Type expected
//
// (15,34): error CS1001: Identifier expected
//
// (15,34): error CS1003: Syntax error, ',' expected
//
// (15,39): error CS1002: ; expected
//
// (15,39): error CS1525: Invalid expression term 'as'
//
// (15,43): error CS1002: ; expected
//
// (15,43): error CS7017: Member definition, statement, or end-of-file expected
//
// (16,27): error CS8997: Unterminated raw string literal.
//
// (16,27): error CS1003: Syntax error, ',' expected
//
// (17,8): error CS1003: Syntax error, ',' expected
//
// (17,12): error CS1026: ) expected
//
// (19,23): error CS1003: Syntax error, 'in' expected
//
// (19,29): error CS0742: A query body must end with a select clause or a group clause
//
// (20,33): error CS1003: Syntax error, 'in' expected
//
// (20,37): error CS0742: A query body must end with a select clause or a group clause
//
// (21,28): error CS1003: Syntax error, 'in' expected
//
// (21,40): error CS0742: A query body must end with a select clause or a group clause
//
// (22,36): error CS1003: Syntax error, 'in' expected
//
// (22,43): error CS0742: A query body must end with a select clause or a group clause
//
// (23,37): error CS1003: Syntax error, 'in' expected
//
// (23,46): error CS0742: A query body must end with a select clause or a group clause
//
// (24,36): error CS1003: Syntax error, 'in' expected
//
// (24,49): error CS0742: A query body must end with a select clause or a group clause
//
// (31,3): error CS1024: Preprocessor directive expected
//
// (32,31): error CS1001: Identifier expected
//
// (32,33): error CS1031: Type expected
//
// (32,33): error CS1001: Identifier expected
//
// (32,33): error CS1003: Syntax error, ',' expected
//
// (32,38): error CS1002: ; expected
//
// (32,38): error CS1525: Invalid expression term 'as'
//
// (32,56): error CS1002: ; expected
//
// (32,56): error CS7017: Member definition, statement, or end-of-file expected
//
// (36,18): error CS1525: Invalid expression term 'int'
//
// (37,18): error CS1525: Invalid expression term 'int'
//
// (38,20): error CS1525: Invalid expression term 'int'
//
// (39,18): error CS1525: Invalid expression term 'int'
//
// (40,15): error CS1525: Invalid expression term 'int'
//
// (43,3): error CS1024: Preprocessor directive expected
//
// (44,3): error CS1024: Preprocessor directive expected
//
// (45,3): error CS1024: Preprocessor directive expected
//
// (46,3): error CS1024: Preprocessor directive expected
//
// (47,3): error CS1024: Preprocessor directive expected
//
// (48,3): error CS1024: Preprocessor directive expected
//
// (49,28): error CS1002: ; expected
//
// (51,32): error CS1001: Identifier expected
//
// (51,32): error CS1003: Syntax error, ',' expected
//
// (51,34): error CS1003: Syntax error, ',' expected
//
// (51,37): error CS1001: Identifier expected
//
// (51,50): error CS1001: Identifier expected
//
// (51,50): error CS1003: Syntax error, ',' expected
//
// (51,52): error CS1003: Syntax error, ',' expected
//
// (51,55): error CS1001: Identifier expected
//
// (51,57): error CS1018: Keyword 'this' or 'base' expected
//
// (51,57): error CS1002: ; expected
//
// (52,18): error CS1525: Invalid expression term ':'
//
// (52,18): error CS1002: ; expected
//
// (52,18): error CS7017: Member definition, statement, or end-of-file expected
//
// (53,27): error CS1001: Identifier expected
//
// (53,27): error CS1003: Syntax error, ',' expected
//
// (54,27): error CS1525: Invalid expression term ':'
//
// (54,27): error CS1002: ; expected
//
// (54,27): error CS7017: Member definition, statement, or end-of-file expected
//
// (55,17): error CS1002: ; expected
//
// (56,29): error CS1002: ; expected
//
// (56,29): error CS7017: Member definition, statement, or end-of-file expected
//
// (57,17): error CS1002: ; expected
//
// (57,37): error CS8641: 'else' cannot start a statement.
//
// (57,37): error CS1003: Syntax error, '(' expected
//
// (57,37): error CS1525: Invalid expression term 'else'
//
// (57,37): error CS1026: ) expected
//
// (57,37): error CS1525: Invalid expression term 'else'
//
// (57,37): error CS1002: ; expected
//
// (58,9): error CS1525: Invalid expression term ':'
//
// (58,9): error CS1002: ; expected
//
// (58,9): error CS7017: Member definition, statement, or end-of-file expected
//
// (59,27): error CS1001: Identifier expected
//
// (59,27): error CS1003: Syntax error, ',' expected
//
// (61,27): error CS1040: Preprocessor directives must appear as the first non-whitespace character on a line
//
// (70,3): error CS1024: Preprocessor directive expected
//
// (71,3): error CS1024: Preprocessor directive expected
//
// (74,48): error CS1001: Identifier expected
//
// (74,48): error CS1003: Syntax error, ',' expected
//
// (74,50): error CS1003: Syntax error, ',' expected
//
// (74,60): error CS1001: Identifier expected
//
// (74,62): error CS1018: Keyword 'this' or 'base' expected
//
// (74,62): error CS1002: ; expected
//
// (75,26): error CS1514: { expected
//
// (75,26): error CS1513: } expected
//
// (75,34): error CS1525: Invalid expression term ':'
//
// (75,34): error CS1002: ; expected
//
// (75,34): error CS7017: Member definition, statement, or end-of-file expected
//
// (79,26): error CS1001: Identifier expected
//
// (79,34): error CS1001: Identifier expected
//
// (79,34): error CS1003: Syntax error, ',' expected
//
// (79,36): error CS1003: Syntax error, ',' expected
//
// (79,46): error CS1001: Identifier expected
//
// (79,55): error CS1001: Identifier expected
//
// (79,55): error CS1003: Syntax error, ',' expected
//
// (79,57): error CS1003: Syntax error, ',' expected
//
// (79,64): error CS1001: Identifier expected
//
// (79,68): error CS1001: Identifier expected
//
// (79,76): error CS1018: Keyword 'this' or 'base' expected
//
// (79,76): error CS1002: ; expected
//
// (84,23): error CS1001: Identifier expected
//
// (84,25): error CS1018: Keyword 'this' or 'base' expected
//
// (84,25): error CS1002: ; expected
//
// (85,15): error CS1024: Preprocessor directive expected
//
// (86,15): error CS1024: Preprocessor directive expected
//
// (87,15): error CS1024: Preprocessor directive expected
//
// (93,22): error CS1001: Identifier expected
//
// (93,24): error CS1018: Keyword 'this' or 'base' expected
//
// (93,24): error CS1002: ; expected
//
// (94,54): error CS1525: Invalid expression term ':'
//
// (94,54): error CS1002: ; expected
//
// (94,54): error CS7017: Member definition, statement, or end-of-file expected
//
// (104,12): error CS1524: Expected catch or finally
//
// (95,20): error CS1514: { expected
//
// (95,20): error CS1513: } expected
//
// (97,33): error CS1002: ; expected
//
// (97,33): error CS1513: } expected
//
// (101,26): error CS1001: Identifier expected
//
// (101,27): error CS1002: ; expected
//
// (101,27): error CS1513: } expected
//
// (104,27): error CS1002: ; expected
//
// (104,27): error CS1513: } expected
//
// (106,24): error CS1514: { expected
//
// (106,24): error CS1513: } expected
//
// (106,38): error CS1002: ; expected
//
// (106,38): error CS7017: Member definition, statement, or end-of-file expected
//
// (119,3): error CS1024: Preprocessor directive expected
//
// (120,3): error CS1024: Preprocessor directive expected
//
// (121,3): error CS1024: Preprocessor directive expected
//
// (125,3): error CS1024: Preprocessor directive expected
//
// (128,3): error CS1024: Preprocessor directive expected
//
// (129,3): error CS1024: Preprocessor directive expected
//
// (133,22): error CS8997: Unterminated raw string literal.
//
// (133,22): error CS1002: ; expected
//
// (135,3): error CS1024: Preprocessor directive expected
//
// (141,15): error CS1003: Syntax error, '(' expected
//
// (141,15): error CS1026: ) expected
//
// (142,39): error CS1003: Syntax error, 'in' expected
//
// (142,49): error CS0742: A query body must end with a select clause or a group clause
//
// (142,49): error CS1002: ; expected
//
// (142,49): error CS7017: Member definition, statement, or end-of-file expected
//
// (142,68): error CS1002: ; expected
//
// (142,68): error CS7017: Member definition, statement, or end-of-file expected
//
// (152,3): error CS1024: Preprocessor directive expected
//
// (153,3): error CS1024: Preprocessor directive expected
//
// (155,31): error CS1001: Identifier expected
//
// (155,33): error CS1031: Type expected
//
// (155,33): error CS1001: Identifier expected
//
// (155,33): error CS1003: Syntax error, ',' expected
//
// (155,38): error CS1002: ; expected
//
// (155,38): error CS1525: Invalid expression term 'as'
//
// (155,44): error CS1002: ; expected
//
// (155,44): error CS7017: Member definition, statement, or end-of-file expected
//
// (160,20): error CS1003: Syntax error, ',' expected
//
// (164,31): error CS1001: Identifier expected
//
// (164,33): error CS1031: Type expected
//
// (164,33): error CS1001: Identifier expected
//
// (164,33): error CS1003: Syntax error, ',' expected
//
// (164,38): error CS1002: ; expected
//
// (164,38): error CS1525: Invalid expression term 'as'
//
// (164,41): error CS1031: Type expected
//
// (164,41): error CS1002: ; expected
//
// (164,41): error CS7017: Member definition, statement, or end-of-file expected
//
// (165,36): error CS1525: Invalid expression term ')'
//
// (166,38): error CS1002: ; expected
//
// (171,26): error CS1525: Invalid expression term '['
//
// (175,6): error CS1003: Syntax error, ',' expected
//
// (178,68): error CS1002: ; expected
//
// (178,71): error CS1002: ; expected
//
// (181,33): error CS1001: Identifier expected
//
// (181,35): error CS1031: Type expected
//
// (181,35): error CS1001: Identifier expected
//
// (181,35): error CS1003: Syntax error, ',' expected
//
// (181,40): error CS1002: ; expected
//
// (181,40): error CS1525: Invalid expression term 'as'
//
// (181,43): error CS1031: Type expected
//
// (181,43): error CS1002: ; expected
//
// (181,43): error CS7017: Member definition, statement, or end-of-file expected
//
// (182,47): error CS0839: Argument missing
//
// (184,5): error CS1002: ; expected
// Error: compilation error

// %%
#@title Refresh the browser page (in most cases, this can be done by pressing the F5 key)

// %%
using System;

void hello()
{
  Console.WriteLine("Hello, Google Colab!");
}

hello();
// Out:
// Hello, Google Colab!
